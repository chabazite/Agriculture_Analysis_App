# %% [markdown]
# # Changing the World through Green Revolution

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## What kind of change has the world seen in population ?

# %%
# %store -r largest_10_pop_df
# %store -r world_bank_df
largest_10_pop_df = largest_10_pop_df[largest_10_pop_df["country"] != 'World']
countries_df = world_bank_df[world_bank_df["country"] != 'World']
world_df = world_bank_df[world_bank_df["country"] == 'World']

# %%
plt.plot(world_df['date'],world_df['population'])

# label the plot
plt.title('Global Population from 1960 to 2021')
plt.xlabel('year')
plt.ylabel('Billion Population')
plt.show()

# %% [markdown]
# ### Top 10 Most Populated Countries

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=largest_10_pop_df, x='date',y='population',hue='country',sort=False)
# label the plot
plt.title('Top 10 Country Population from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('Billion Population')
plt.show()

# %% [markdown]
# ## How have living conditions been impacted?

# %%
largest_10_urban = countries_df[countries_df['date']=='2021'].nlargest(n=10,columns='total_urban_pop')

largest_10_list = [country for country in largest_10_urban['country']]

top_10_urban_pop_df = countries_df[countries_df['country'].isin(largest_10_list)]

fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=top_10_urban_pop_df, x='date', y='total_urban_pop',hue='country',sort=False)
# label the plot
plt.title('Top 10 Country Urban Population(2021) Growth from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('Billion Population')
plt.show()

# %%
largest_10_rural = countries_df[countries_df['date']=='2021'].nlargest(n=10,columns='total_rural_pop')

largest_10_list = [country for country in largest_10_rural['country']]

top_10_rural_pop_df = countries_df[countries_df['country'].isin(largest_10_list)]

fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=top_10_rural_pop_df, x='date', y='total_rural_pop',hue='country',sort=False)
# label the plot
plt.title('Top 10 Country Rural Population(2021) Growth from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('Billion Population')
plt.show()

# %% [markdown]
# ## How has land development changed?

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=world_df, x='date',y='total_land_sqkm',sort=False)
# label the plot
plt.title('World Land (sq. km) from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('Billion Population')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
largest_10_land = countries_df[countries_df['date']=='2021'].nlargest(n=10,columns='total_ag_land')

largest_10_list = [country for country in largest_10_rural['country']]

top_10_land_df = countries_df[countries_df['country'].isin(largest_10_list)]

fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=top_10_land_df, x='date', y='total_ag_land',hue='country',sort=False)
# label the plot
plt.title('Top 10 Largest Land Countries Total Agricultural Land (sq. km) from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('square km')
plt.show()

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=top_10_urban_pop_df, x='date', y='total_ag_land',hue='country',sort=False)
# label the plot
plt.title('Top 10 Largest Urban Countries Total Agricultural Land (sq. km) from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('square km')
plt.show()

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=top_10_rural_pop_df, x='date', y='total_ag_land',hue='country',sort=False)
# label the plot
plt.title('Top 10 Largest Rural Countries Total Agricultural Land (sq. km) from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('square km')
plt.show()

# %%
top_10_land_df
# Out:
#           country       date   population  total_land_sqkm   forest_%  \
# 3968   Bangladesh 2021-01-01  166303494.0         130170.0        NaN
# 3969   Bangladesh 2020-01-01  164689383.0         130170.0  14.468772
# 3970   Bangladesh 2019-01-01  163046173.0         130170.0  14.468772
# 3971   Bangladesh 2018-01-01  161376713.0         130170.0  14.468772
# 3972   Bangladesh 2017-01-01  159685421.0         130170.0  14.468772
# ...           ...        ...          ...              ...        ...
# 16177     Vietnam 1964-01-01   36780001.0         325490.0        NaN
# 16178     Vietnam 1963-01-01   35721213.0         325490.0        NaN
# 16179     Vietnam 1962-01-01   34683410.0         325490.0        NaN
# 16180     Vietnam 1961-01-01   33666111.0         325490.0        NaN
# 16181     Vietnam 1960-01-01   32670048.0              NaN        NaN
#
#          crop_%  agricultural_%   arable_%  cereal_grain_hectare  rural_pop_%  \
# 3968        NaN             NaN        NaN                   NaN       61.054
# 3969        NaN             NaN        NaN                   NaN       61.823
# 3970        NaN             NaN        NaN                   NaN       62.595
# 3971   6.376277       70.694476  59.708842            12695088.0       63.368
# 3972   6.376277       70.579473  59.593839            12430005.0       64.142
# ...         ...             ...        ...                   ...          ...
# 16177  1.490061       19.376939  17.051215             5244800.0       83.936
# 16178  1.474700       19.361578  17.051215             4769270.0       84.286
# 16179  1.459338       19.346216  17.051215             5150880.0       84.631
# 16180  1.443977       19.330855  17.051215             5004200.0       84.969
# 16181       NaN             NaN        NaN                   NaN       85.300
#
#        ...  mortality_under5  Total_Greenhouse_gases  CO2_emmission  \
# 3968   ...               NaN                     NaN            NaN
# 3969   ...              29.1                     NaN            NaN
# 3970   ...              30.7           215940.002441   90739.997864
# 3971   ...              32.4           208000.000000   83449.996948
# 3972   ...              34.2           203080.001831   79339.996338
# ...    ...               ...                     ...            ...
# 16177  ...              86.6                     NaN            NaN
# 16178  ...               NaN                     NaN            NaN
# 16179  ...               NaN                     NaN            NaN
# 16180  ...               NaN                     NaN            NaN
# 16181  ...               NaN                     NaN            NaN
#
#        Poverty_under1_90_per_day  total_urban_pop  total_rural_pop  \
# 3968                         NaN     6.476856e+07     1.015349e+08
# 3969                         NaN     6.287347e+07     1.018159e+08
# 3970                         NaN     6.098742e+07     1.020588e+08
# 3971                         NaN     5.911552e+07     1.022612e+08
# 3972                         NaN     5.726000e+07     1.024254e+08
# ...                          ...              ...              ...
# 16177                        NaN     5.908339e+06     3.087166e+07
# 16178                        NaN     5.613231e+06     3.010798e+07
# 16179                        NaN     5.330493e+06     2.935292e+07
# 16180                        NaN     5.060353e+06     2.860576e+07
# 16181                        NaN     4.802497e+06     2.786755e+07
#
#        total_forest_land  total_ag_land  total_perm_crop_land  \
# 3968                 NaN            NaN                   NaN
# 3969             18834.0            NaN                   NaN
# 3970             18834.0            NaN                   NaN
# 3971             18834.0        92023.0                8300.0
# 3972             18834.0        91873.3                8300.0
# ...                  ...            ...                   ...
# 16177                NaN        63070.0                4850.0
# 16178                NaN        63020.0                4800.0
# 16179                NaN        62970.0                4750.0
# 16180                NaN        62920.0                4700.0
# 16181                NaN            NaN                   NaN
#
#        total_arable_land
# 3968                 NaN
# 3969                 NaN
# 3970                 NaN
# 3971             77723.0
# 3972             77573.3
# ...                  ...
# 16177            55500.0
# 16178            55500.0
# 16179            55500.0
# 16180            55500.0
# 16181                NaN
#
# [620 rows x 26 columns]

# %%
fig, axs = plt.subplots(figsize=(15, 15))

top_10_land_df['%_crop_per_ag_land'] = top_10_land_df['total_perm_crop_land']/top_10_land_df['total_ag_land']


sns.lineplot(ax = axs, data=top_10_land_df, x='date', y='%_crop_per_ag_land',hue='country',sort=False)
# label the plot
plt.title('Top 10 Largest Land Countries % Crop Land in Agricultural Land from 1960 to 2021')
plt.legend()
plt.xlabel('% devoted Ag Land devoted to crops')
plt.xticks(rotation=45)
plt.ylabel('square km')
plt.show()
# Out:
# C:\Users\ingal\AppData\Local\Temp\ipykernel_1528\966967583.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_10_land_df['%_crop_per_ag_land'] = top_10_land_df['total_perm_crop_land']/top_10_land_df['total_ag_land']

# %%
fig, axs = plt.subplots(figsize=(15, 15))

largest_10_pop_df['%_crop_per_ag_land'] = largest_10_pop_df['total_perm_crop_land']/largest_10_pop_df['total_ag_land']


sns.lineplot(ax = axs, data=largest_10_pop_df, x='date', y='%_crop_per_ag_land',hue='country',sort=False)
# label the plot
plt.title('Top 10 Largest Population Countries % Crop Land in Agricultural Land (sq. km) from 1960 to 2021')
plt.legend()
plt.xlabel('% devoted Ag Land devoted to crops')
plt.xticks(rotation=45)
plt.ylabel('square km')
plt.show()
# Out:
# C:\Users\ingal\AppData\Local\Temp\ipykernel_1528\2833104768.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   largest_10_pop_df['%_crop_per_ag_land'] = largest_10_pop_df['total_perm_crop_land']/largest_10_pop_df['total_ag_land']

# %%
largest_10_pop_df

fig, axs = plt.subplots(figsize=(15, 15))

sns.barplot(ax = axs, data=largest_10_pop_df, x='country', y='%_crop_per_ag_land')
# label the plot
plt.title('Top 10 Largest Population Countries % Crop Land in Agricultural Land (sq. km) from 1960 to 2021')
plt.legend()
plt.xlabel('Countries')
plt.xticks(rotation=45)
plt.ylabel('% devoted Ag Land devoted to crops')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
top_10_pop_2021
# Out:
#                   country       date    population  total_land_sqkm  \
# 3971           Bangladesh 2018-01-01  1.613767e+08         130170.0
# 4653               Brazil 2018-01-01  2.094693e+08        8358140.0
# 5583                China 2018-01-01  1.402760e+09        9424702.9
# 8559                India 2018-01-01  1.352642e+09        2973190.0
# 8621            Indonesia 2018-01-01  2.676705e+08        1877519.0
# 10915              Mexico 2018-01-01  1.261908e+08        1943950.0
# 11969             Nigeria 2018-01-01  1.958747e+08         910770.0
# 12279            Pakistan 2018-01-01  2.122283e+08         770880.0
# 13023  Russian Federation 2018-01-01  1.444779e+08       16376870.0
# 15813       United States 2018-01-01  3.268382e+08        9147420.0
#
#         forest_%     crop_%  agricultural_%   arable_%  cereal_grain_hectare  \
# 3971   14.468772   6.376277       70.694476  59.708842            12695088.0
# 4653   59.708428   0.927958       28.341090   6.671580            21445930.0
# 5583   22.941735   1.719524       56.079083  12.678246           100662708.0
# 8559   24.091027   4.372408       60.431389  52.608814            98008000.0
# 8621   49.716818  13.315444       33.182088  14.007848            21675360.0
# 10915  33.924540   1.392526       54.986497  12.297127             9426483.0
# 11969  24.104384   7.136818       75.895616  37.331050            17373539.0
# 12279   4.940561   1.028694       47.089041  39.574253            13680217.0
# 13023  49.784336   0.109484       13.158436   7.428098            41983108.0
# 15813  33.866926   0.295165       44.363367  17.243857            53839362.0
#
#        rural_pop_%  ...  Total_Greenhouse_gases  CO2_emmission  \
# 3971        63.368  ...            2.080000e+05   8.345000e+04
# 4653        13.431  ...            1.046580e+06   4.339900e+05
# 5583        40.848  ...            1.247109e+07   1.050293e+07
# 8559        65.970  ...            3.388910e+06   2.451930e+06
# 8621        44.675  ...            9.580800e+05   5.769900e+05
# 10915       19.844  ...            6.542500e+05   4.525700e+05
# 11969       49.656  ...            2.996200e+05   1.098900e+05
# 12279       63.334  ...            4.216200e+05   1.873100e+05
# 13023       25.567  ...            2.419470e+06   1.661000e+06
# 15813       17.744  ...            6.121630e+06   4.975310e+06
#
#        Poverty_under1_90_per_day  total_urban_pop  total_rural_pop  \
# 3971                         NaN     5.911552e+07     1.022612e+08
# 4653                         4.7     1.813355e+08     2.813382e+07
# 5583                         0.3     8.297606e+08     5.729994e+08
# 8559                         NaN     4.603042e+08     8.923381e+08
# 8621                         3.6     1.480887e+08     1.195818e+08
# 10915                        2.7     1.011495e+08     2.504130e+07
# 11969                       39.1     9.861115e+07     9.726353e+07
# 12279                        3.6     7.781562e+07     1.344127e+08
# 13023                        0.0     1.075392e+08     3.693865e+07
# 15813                        1.0     2.688440e+08     5.799417e+07
#
#        total_forest_land  total_ag_land  total_perm_crop_land  \
# 3971             18834.0      92023.000                8300.0
# 4653           4990514.0    2368788.010               77560.0
# 5583           2162190.4    5285287.000              162060.0
# 8559            716272.0    1796740.000              130000.0
# 8621            933442.7     623000.000              250000.0
# 10915           659476.1    1068910.000               27070.0
# 11969           219535.5     691234.500               65000.0
# 12279            38085.8     363000.000                7930.0
# 13023          8153116.0    2154940.000               17930.0
# 15813          3097950.0    4058103.538               27000.0
#
#        total_arable_land  %_crop_per_ag_land
# 3971             77723.0            0.090195
# 4653            557620.0            0.032742
# 5583           1194887.0            0.030662
# 8559           1564160.0            0.072353
# 8621            263000.0            0.401284
# 10915           239050.0            0.025325
# 11969           340000.0            0.094035
# 12279           305070.0            0.021846
# 13023          1216490.0            0.008320
# 15813          1577368.0            0.006653
#
# [10 rows x 27 columns]

# %%
top_10_pop_2018 =  largest_10_pop_df[largest_10_pop_df['date']=='2018-01-01']
temp_df = pd.concat([world_2018,top_10_pop_2018])

# %%
temp_df=temp_df.set_index('country')

# %%
temp_df.drop(columns='date',inplace=True)

# %%
temp_df.loc['Other'] = temp_df.loc['World'] - (temp_df.loc['Bangladesh'] + temp_df.loc['Brazil'] + temp_df.loc['China'] + temp_df.loc['India'] + temp_df.loc['Indonesia'] + temp_df.loc['Mexico'] + temp_df.loc['Nigeria'] + temp_df.loc['Pakistan'] + temp_df.loc['Russian Federation'] + temp_df.loc['United States'])

# %%
temp_df.loc['Top_10_Pop'] = temp_df.loc['Bangladesh'] + temp_df.loc['Brazil'] + temp_df.loc['China'] + temp_df.loc['India'] + temp_df.loc['Indonesia'] + temp_df.loc['Mexico'] + temp_df.loc['Nigeria'] + temp_df.loc['Pakistan'] + temp_df.loc['Russian Federation'] + temp_df.loc['United States']

# %%
temp_df=temp_df.drop(['Bangladesh','Brazil','China','India','Indonesia','Pakistan','Mexico','Nigeria','United States','Russian Federation'])

# %%
temp_df=temp_df.reset_index()

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.barplot(ax = axs, data=top_10_pop_2018, x='country', y='total_ag_land')
# label the plot
plt.title('Top 10 Largest Population Countries % Crop Land in Agricultural Land (sq. km) 2018')
plt.legend()
plt.xlabel('Countries')
plt.xticks(rotation=45)
plt.ylabel('billion sq km')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.barplot(ax = axs, data=temp_df, x='country', y='total_ag_land')
# label the plot
plt.title('Top 10 Largest Population Countries % Crop Land in Agricultural Land (sq. km) 2018')
plt.legend()
plt.xlabel('Countries')
plt.xticks(rotation=45)
plt.ylabel('billion sq km')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=world_df, x='date',y='total_forest_land',sort=False)
# label the plot
plt.title('World Forest Land (sq. km) from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('10 billion sq km')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=largest_10_pop_df, x='date',y='total_forest_land', hue = 'country', sort=False)
# label the plot
plt.title('Top 10 populated Counties Forest Land (sq. km) from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('billion sq km')
plt.show()

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=top_10_urban_pop_df, x='date',y='total_forest_land', hue = 'country', sort=False)
# label the plot
plt.title('Top 10 Urban Pop Counties Forest Land (sq. km) from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('billion sq km')
plt.show()

# %% [markdown]
# ## How has Agriculture demand and economics changed?
# cereal_grain_hectare
# male_employement_ag
# female_employment_ag
# fertilizer_consump
# cereal_yield_hectare
# total_gdp_ag_forestry_fishing

# %% [markdown]
# ## How have major world issues changed?
