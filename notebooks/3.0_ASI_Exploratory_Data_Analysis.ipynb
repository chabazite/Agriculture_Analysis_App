# %% [markdown]
# # Changing the World through Green Revolution

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## What kind of change has the world seen in population ?

# %%
# %store -r largest_10_pop_df
# %store -r world_bank_df
largest_10_pop_df = largest_10_pop_df[largest_10_pop_df["country"] != 'World']
countries_df = world_bank_df[world_bank_df["country"] != 'World']
world_df = world_bank_df[world_bank_df["country"] == 'World']

# %%
plt.plot(world_df['date'],world_df['population'])

# label the plot
plt.title('Global Population from 1960 to 2021')
plt.xlabel('year')
plt.ylabel('Billion Population')
plt.show()

# %% [markdown]
# ### Top 10 Most Populated Countries

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=largest_10_pop_df, x='date',y='population',hue='country',sort=False)
# label the plot
plt.title('Top 10 Country Population from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('Billion Population')
plt.show()

# %% [markdown]
# ## How have living conditions been impacted?

# %%
largest_10_urban = countries_df[countries_df['date']=='2021'].nlargest(n=10,columns='total_urban_pop')

largest_10_list = [country for country in largest_10_urban['country']]

top_10_urban_pop_df = countries_df[countries_df['country'].isin(largest_10_list)]

fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=top_10_urban_pop_df, x='date', y='total_urban_pop',hue='country',sort=False)
# label the plot
plt.title('Top 10 Country Urban Population(2021) Growth from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('Billion Population')
plt.show()

# %%
largest_10_rural = countries_df[countries_df['date']=='2021'].nlargest(n=10,columns='total_rural_pop')

largest_10_list = [country for country in largest_10_rural['country']]

top_10_rural_pop_df = countries_df[countries_df['country'].isin(largest_10_list)]

fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=top_10_rural_pop_df, x='date', y='total_rural_pop',hue='country',sort=False)
# label the plot
plt.title('Top 10 Country Rural Population(2021) Growth from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('Billion Population')
plt.show()

# %% [markdown]
# ## How has land development changed?

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=world_df, x='date',y='total_land_sqkm',sort=False)
# label the plot
plt.title('World Land (sq. km) from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('Billion Population')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
largest_10_land = countries_df[countries_df['date']=='2021'].nlargest(n=10,columns='total_ag_land')

largest_10_list = [country for country in largest_10_rural['country']]

top_10_land_df = countries_df[countries_df['country'].isin(largest_10_list)]

fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=top_10_land_df, x='date', y='total_ag_land',hue='country',sort=False)
# label the plot
plt.title('Top 10 Largest Land Countries Total Agricultural Land (sq. km) from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('square km')
plt.show()

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=top_10_urban_pop_df, x='date', y='total_ag_land',hue='country',sort=False)
# label the plot
plt.title('Top 10 Largest Urban Countries Total Agricultural Land (sq. km) from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('square km')
plt.show()

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=top_10_rural_pop_df, x='date', y='total_ag_land',hue='country',sort=False)
# label the plot
plt.title('Top 10 Largest Rural Countries Total Agricultural Land (sq. km) from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('square km')
plt.show()

# %%
largest_10_pop_df_2018 = largest_10_pop_df[largest_10_pop_df['date']== '2018-01-01']

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.barplot(ax = axs, data=largest_10_pop_df_2018, x='country', y='total_ag_land')
# label the plot
plt.title('Top 10 Largest Pop Countries Total Agricultural Land (sq. km) 2018')
plt.legend()
plt.xlabel('Country')
plt.xticks(rotation=45)
plt.ylabel('square km')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
world_vs_10_pop_df=largest_10_pop_df_2018.set_index('country')

# %%
world_vs_10_pop_df.drop(columns=('date'),inplace=True)

# %%
world_vs_10_pop_df.loc['Top_10']= world_vs_10_pop_df.loc['Bangladesh']+ world_vs_10_pop_df.loc['Brazil'] + world_vs_10_pop_df.loc['China'] + world_vs_10_pop_df.loc['India']+ world_vs_10_pop_df.loc['Indonesia'] + world_vs_10_pop_df.loc['Mexico']+ world_vs_10_pop_df.loc['Nigeria'] + world_vs_10_pop_df.loc['Pakistan']+ world_vs_10_pop_df.loc['Russian Federation'] + world_vs_10_pop_df.loc['United States']

# %%
temp_world =world_df[world_df['date']=='2018-01-01'].set_index('country').drop(columns=('date'))

# %%
world_vs_10_pop_df.loc['Other'] = temp_world.loc['World'] - world_vs_10_pop_df.loc['Top_10']

# %%
world_vs_10_pop_df.loc['Top_10']= world_vs_10_pop_df.loc['Bangladesh']+ world_vs_10_pop_df.loc['Brazil'] + world_vs_10_pop_df.loc['China'] + world_vs_10_pop_df.loc['India']+ world_vs_10_pop_df.loc['Indonesia'] + world_vs_10_pop_df.loc['Mexico']+ world_vs_10_pop_df.loc['Nigeria'] + world_vs_10_pop_df.loc['Pakistan']+ world_vs_10_pop_df.loc['Russian Federation'] + world_vs_10_pop_df.loc['United States']

# %%
world_vs_10_pop_df=world_vs_10_pop_df.reset_index()

# %%
world_vs_10_pop_df=world_vs_10_pop_df.iloc[10:12]

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.barplot(ax = axs, data=world_vs_10_pop_df, x='country', y='total_ag_land')
# label the plot
plt.title('Top 10 Largest Pop Countries Total Agricultural Land (sq. km) 2018')
plt.legend()
plt.xlabel('Country')
plt.xticks(rotation=45)
plt.ylabel('square km')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.barplot(ax = axs, data=world_vs_10_pop_df, x='country', y='total_arable_land')
# label the plot
plt.title('Top 10 Largest Pop Countries Total Arable Land (sq. km) 2018')
plt.legend()
plt.xlabel('Country')
plt.xticks(rotation=45)
plt.ylabel('square km')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.barplot(ax = axs, data=world_vs_10_pop_df, x='country', y='total_perm_crop_land')
# label the plot
plt.title('Top 10 Largest Pop Countries Total perm crop Land (sq. km) 2018')
plt.legend()
plt.xlabel('Country')
plt.xticks(rotation=45)
plt.ylabel('square km')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
world_vs_10_pop_df
# Out:
#    country    population  total_land_sqkm    forest_%     crop_%  \
# 10  Top_10  4.399529e+09     5.191361e+07  317.547528  36.674298
# 11   Other  3.203188e+09     7.803567e+07         NaN -35.353972
#
#     agricultural_%    arable_%  cereal_grain_hectare  rural_pop_%  \
# 10      484.221083  259.549714           390789795.0   404.437000
# 11     -447.317563 -248.724544           337575404.0  -359.714975
#
#     urban_pop_%  ...  mortality_under5  Total_Greenhouse_gases  CO2_emmission  \
# 10   595.563000  ...             333.8            2.798925e+07   2.143537e+07
# 11  -540.285025  ...            -295.0            1.814355e+07   1.285398e+07
#
#     Poverty_under1_90_per_day  total_urban_pop  total_rural_pop  \
# 10                        NaN     2.332564e+09     2.066965e+09
# 11                        NaN     1.870064e+09     1.333124e+09
#
#     total_forest_land  total_ag_land  total_perm_crop_land  total_arable_land
# ...

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.barplot(ax = axs, data=world_vs_10_pop_df, x='country', y='total_perm_crop_land')
# label the plot
plt.title('Top 10 Largest Pop Countries Total Perm Crop Land (sq. km) 2018')
plt.legend()
plt.xlabel('Country')
plt.xticks(rotation=45)
plt.ylabel('square km')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## How has Agriculture demand and economics changed?
# cereal_grain_hectare
# male_employement_ag
# female_employment_ag
# fertilizer_consump
# cereal_yield_hectare
# total_gdp_ag_forestry_fishing

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=top_10_rural_pop_df, x='date', y='cereal_grain_hectare',hue='country',sort=False)
# label the plot
plt.title('Top 10 Largest Rural Countries Total cereal grain prodcution hectare from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('hectare')
plt.show()

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=largest_10_pop_df, x='date', y='cereal_grain_hectare',hue='country',sort=False)
# label the plot
plt.title('Top 10 Largest pop Countries Total cereal grain prodcution hectare from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('hectare')
plt.show()

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=top_10_urban_pop_df, x='date', y='cereal_grain_hectare',hue='country',sort=False)
# label the plot
plt.title('Top 10 Largest urban Countries Total cereal grain prodcution hectare from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('hectare')
plt.show()

# %%
#cereal production hectare/population
largest_10_pop_df['cereal_population'] = largest_10_pop_df['cereal_grain_hectare'] / largest_10_pop_df['population']
# Out:
# C:\Users\ingal\AppData\Local\Temp\ipykernel_5164\1054125917.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   largest_10_pop_df['cereal_population'] = largest_10_pop_df['cereal_grain_hectare'] / largest_10_pop_df['population']

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=largest_10_pop_df, x='date', y='cereal_population',hue='country',sort=False)
# label the plot
plt.title('Top 10 Largest pop Countries Total cereal grain prodcution hectare from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('hectare per person')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.barplot(ax = axs, data=world_vs_10_pop_df, x='country', y='cereal_grain_hectare')
# label the plot
plt.title('Top 10 Largest Pop Countries Total cereal grain produces _hectrare(sq. km) 2018')
plt.legend()
plt.xlabel('Country')
plt.xticks(rotation=45)
plt.ylabel('Hectare')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=largest_10_pop_df, x='date', y='total_gdp_ag_forestry_fishing',hue='country',sort=False)
# label the plot
plt.title('Top 10 Largest pop Countries Total GDP from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('GDP')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=world_df, x='date', y='total_gdp_ag_forestry_fishing',hue='country',sort=False)
# label the plot
plt.title('Top 10 Largest pop Countries Total GDP from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('GDP')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#minumim GDP for ag was 2006. Recession
world_df[world_df['total_gdp_ag_forestry_fishing']==world_df['total_gdp_ag_forestry_fishing'].min()]
# Out:
#      country       date    population  total_land_sqkm   forest_%    crop_%  \
# 2991   World 2006-01-01  6.592712e+09     1.298854e+08  30.971231  1.169305
#
#       agricultural_%   arable_%  cereal_grain_hectare  rural_pop_%  ...  \
# 2991       36.826946  10.536554           673481951.0    50.346734  ...
#
#       mortality_under5  Total_Greenhouse_gases  CO2_emmission  \
# 2991              60.0            3.848092e+07   2.830293e+07
#
#       Poverty_under1_90_per_day  total_urban_pop  total_rural_pop  \
# 2991                       20.1     3.273497e+09     3.319215e+09
#
#       total_forest_land  total_ag_land  total_perm_crop_land  \
# 2991       4.022711e+07   4.783283e+07          1.518757e+06
#
#       total_arable_land
# 2991       1.368545e+07
#
# [1 rows x 26 columns]

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=world_df, x='date', y='fertilizer_consump',hue='country',sort=False)
# label the plot
plt.title('Top 10 Largest pop Countries Total fertilizer consuption from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('fertilizer consumption')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=largest_10_pop_df, x='date', y='fertilizer_consump', hue='country',sort=False)
# label the plot
plt.title('Top 10 Largest pop Countries Total fertilizer consumption from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('fertilizer consumption')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
largest_10_pop_df['fert_cereal_yield']=  largest_10_pop_df['fertilizer_consump'] / largest_10_pop_df['cereal_yield_hectare']
# Out:
# C:\Users\ingal\AppData\Local\Temp\ipykernel_5164\4114318065.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   largest_10_pop_df['fert_cereal_yield']=  largest_10_pop_df['fertilizer_consump'] / largest_10_pop_df['cereal_yield_hectare']

# %%
world_df['fert_cereal_yield']= world_df['fertilizer_consump']  / world_df['cereal_yield_hectare']
# Out:
# C:\Users\ingal\AppData\Local\Temp\ipykernel_5164\4223970813.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   world_df['fert_cereal_yield']= world_df['fertilizer_consump']  / world_df['cereal_yield_hectare']

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=world_df, x='date', y='fert_cereal_yield', hue='country',sort=False)
# label the plot
plt.title('Top 10 Largest pop Countries Total fertilizer consumption per cereal yield from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('fertilizer consumption per cereal yield')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=largest_10_pop_df, x='date', y='fert_cereal_yield', hue='country',sort=False)
# label the plot
plt.title('Top 10 Largest pop Countries Total fertilizer consumption per cereal yield from 1960 to 2021')
plt.legend()
plt.xlabel('year')
plt.xticks(rotation=45)
plt.ylabel('fertilizer consumption per cereal yield')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## How have major world issues changed?

# %%
world_df.columns
# Out:
# Index(['country', 'date', 'population', 'total_land_sqkm', 'forest_%',
#        'crop_%', 'agricultural_%', 'arable_%', 'cereal_grain_hectare',
#        'rural_pop_%', 'urban_pop_%', 'male_employement_ag',
#        'female_employment_ag', 'fertilizer_consump', 'cereal_yield_hectare',
#        'total_gdp_ag_forestry_fishing', 'mortality_under5',
#        'Total_Greenhouse_gases', 'CO2_emmission', 'Poverty_under1_90_per_day',
#        'total_urban_pop', 'total_rural_pop', 'total_forest_land',
#        'total_ag_land', 'total_perm_crop_land', 'total_arable_land',
#        'fert_cereal_yield'],
#       dtype='object')

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=world_df, x='date', y='Total_Greenhouse_gases', hue='country',sort=False)
# label the plot
plt.title('Wolrd Total greenhouse gases (sq. km) 1960-2018')
plt.legend()
plt.xlabel('Year')
plt.xticks(rotation=45)
plt.ylabel('Greenhouse Gases')
plt.show()

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=world_df, x='date', y='CO2_emmission', hue='country',sort=False)
# label the plot
plt.title('Wolrd Total CO2 1960-2018')
plt.legend()
plt.xlabel('Year')
plt.xticks(rotation=45)
plt.ylabel('CO2')
plt.show()

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=world_df, x='date', y='mortality_under5', hue='country',sort=False)
# label the plot
plt.title('Wolrd Total mortality under 5 1960-2018')
plt.legend()
plt.xlabel('Year')
plt.xticks(rotation=45)
plt.ylabel('deaths')
plt.show()

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=world_df, x='date', y='Poverty_under1_90_per_day', hue='country',sort=False)
# label the plot
plt.title('Wolrd Total Poverty under 5 1960-2018')
plt.legend()
plt.xlabel('Year')
plt.xticks(rotation=45)
plt.ylabel('Poverty')
plt.show()

# %%
fig, axs = plt.subplots(figsize=(15, 15))

sns.lineplot(ax = axs, data=top_10_rural_pop_df, x='date', y='Poverty_under1_90_per_day', hue='country',sort=False)
# label the plot
plt.title('Wolrd Total Poverty under 5 1960-2018')
plt.legend()
plt.xlabel('Year')
plt.xticks(rotation=45)
plt.ylabel('Poverty')
plt.show()
